# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = 'https://raw.githubusercontent.com/fernandoawari/calculadora-aluguel-turma-set-20/main/2-manipulacao/dados_aluguel_ml_sao_paulo_preprocessado.csv'

# %%
df=pd.read_csv('/Volumes/GoogleDrive/My Drive/DS Cohorts - Recording and Materials/Awari DS - Turma Set 20/calculadora-aluguel-turma-set-20/2-manipulacao/dados_aluguel_ml_sao_paulo_preprocessado.csv')

# %%
df.head()
# Out:
#     zona                                    enderecos_lista  area  quartos  \
# 0  norte  Praça Rafael Mendes De Carvalho, Jardim Paraís...  50.0      2.0
# 1  norte  Rua Almirante Noronha, Jardim São Paulo, São P...  76.0      3.0
# 2  norte  Rua Cássio De Almeida, Vila Guilherme, São Pau...  30.0      1.0
# 3  norte  Rua Cabo José Da Silva, Parque Novo Mundo, São...  80.0      3.0
# 4  norte  Parque Domingos Luís, Jardim São Paulo, São Pa...  70.0      2.0
#
#    aluguel
# 0     1150
# 1     1480
# 2      800
# 3     1180
# 4     1300

# %%
df.describe(include='all')
# Out:
#          zona                                    enderecos_lista         area  \
# count    1344                                               1344  1341.000000
# unique      4                                               1068          NaN
# top     leste  Rua Voluntários Da Pátria, Santana, São Paulo ...          NaN
# freq      336                                                 13          NaN
# mean      NaN                                                NaN   112.697987
# std       NaN                                                NaN   259.503149
# min       NaN                                                NaN     1.000000
# 25%       NaN                                                NaN    48.000000
# 50%       NaN                                                NaN    67.000000
# 75%       NaN                                                NaN   106.000000
# max       NaN                                                NaN  7800.000000
#
# ...

# %%
df.describe().T
# Out:
#           count         mean           std    min     25%     50%     75%  \
# area     1341.0   112.697987    259.503149    1.0    48.0    67.0   106.0
# quartos  1273.0     2.106834      0.882869    1.0     1.0     2.0     3.0
# aluguel  1344.0  4396.404762  29225.842756  299.0  1500.0  2200.0  3577.5
#
#               max
# area       7800.0
# quartos       5.0
# aluguel  870000.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1344 entries, 0 to 1343
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   zona             1344 non-null   object
#  1   enderecos_lista  1344 non-null   object
#  2   area             1341 non-null   float64
#  3   quartos          1273 non-null   float64
#  4   aluguel          1344 non-null   int64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 52.6+ KB

# %%
df.shape
# Out:
# (1344, 5)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1344, step=1)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1344, step=1)

# %%
df['zona'].value_counts()
# Out:
# leste    336
# norte    336
# sul      336
# oeste    336
# Name: zona, dtype: int64

# %%
df['aluguel'].hist()

# %%
y = [10, 30, 20, 40]
x = [1, 3, 5, 7]
plt.scatter(x, y)

# %%
df.head()
# Out:
#     zona                                    enderecos_lista  area  quartos  \
# 0  norte  Praça Rafael Mendes De Carvalho, Jardim Paraís...  50.0      2.0
# 1  norte  Rua Almirante Noronha, Jardim São Paulo, São P...  76.0      3.0
# 2  norte  Rua Cássio De Almeida, Vila Guilherme, São Pau...  30.0      1.0
# 3  norte  Rua Cabo José Da Silva, Parque Novo Mundo, São...  80.0      3.0
# 4  norte  Parque Domingos Luís, Jardim São Paulo, São Pa...  70.0      2.0
#
#    aluguel
# 0     1150
# 1     1480
# 2      800
# 3     1180
# 4     1300

# %%
aluguel_maximo = 40000

# %%
filtro_aluguel_maximo = df['aluguel']<=aluguel_maximo
df_filtrado = df[filtro_aluguel_maximo]

# %%
df.head()
# Out:
#     zona                                    enderecos_lista  area  quartos  \
# 0  norte  Praça Rafael Mendes De Carvalho, Jardim Paraís...  50.0      2.0
# 1  norte  Rua Almirante Noronha, Jardim São Paulo, São P...  76.0      3.0
# 2  norte  Rua Cássio De Almeida, Vila Guilherme, São Pau...  30.0      1.0
# 3  norte  Rua Cabo José Da Silva, Parque Novo Mundo, São...  80.0      3.0
# 4  norte  Parque Domingos Luís, Jardim São Paulo, São Pa...  70.0      2.0
#
#    aluguel
# 0     1150
# 1     1480
# 2      800
# 3     1180
# 4     1300

# %%
df_filtrado = df.query('aluguel<=@aluguel_maximo')

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df_filtrado['area'], df_filtrado['aluguel'], alpha=0.2)
#x = [0, 400, 1000]
#y = [0, 10000, 20000]
#plt.plot(x, y, c='r')
plt.xlabel('Área')
plt.ylabel('Aluguel')
# Out:
# Text(0, 0.5, 'Aluguel')

# %%
df_filtrado['aluguel'].hist()

# %%
sns.pairplot(df_filtrado, kind='reg', hue='zona')

# %%
sns.pairplot(df_filtrado, hue='zona')

# %%
num_cols = ['area', 'quartos', 'aluguel']

# %%
df_log = df_filtrado.copy()

# %%
import numpy as np
np.log1p(0)
# Out:
# 0.0

# %%
df_log[num_cols] = df_log[num_cols].apply(np.log1p)

# %%
g = sns.pairplot(df_log, hue='zona', plot_kws={'alpha':0.1})

# %%
df_filtrado.corr()
# Out:
#              area   quartos   aluguel
# area     1.000000  0.646015  0.722388
# quartos  0.646015  1.000000  0.481179
# aluguel  0.722388  0.481179  1.000000

# %%
sns.heatmap(df_filtrado.corr(), annot=True, center=0, cmap="YlGnBu")

# %%
df_filtrado.boxplot('aluguel')

# %%
sns.boxplot(x=df_filtrado['aluguel'])

# %%
tips = sns.load_dataset("tips")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.boxplot(x="day", y="total_bill", data=tips)

# %%
df_filtrado
# Out:
#        zona                                    enderecos_lista   area  \
# 0     norte  Praça Rafael Mendes De Carvalho, Jardim Paraís...   50.0
# 1     norte  Rua Almirante Noronha, Jardim São Paulo, São P...   76.0
# 2     norte  Rua Cássio De Almeida, Vila Guilherme, São Pau...   30.0
# 3     norte  Rua Cabo José Da Silva, Parque Novo Mundo, São...   80.0
# 4     norte  Parque Domingos Luís, Jardim São Paulo, São Pa...   70.0
# ...     ...                                                ...    ...
# 1339  oeste  Rua Piauí, Higienópolis, São Paulo Zona Oeste,...  480.0
# 1340  oeste  Rua Doutor Aires Martins Torres, Vila São Fran...  620.0
# 1341  oeste  Rua Doutor Martins De Oliveira, Jardim Londrin...   64.0
# 1342  oeste  Rua Natingui, Vila Madalena, São Paulo Zona Oe...   44.0
# 1343  oeste  Rua Amaro Cavalheiro, Pinheiros, São Paulo Zon...  150.0
#
#       quartos  aluguel
# 0         2.0     1150
# 1         3.0     1480
# 2         1.0      800
# 3         3.0     1180
# ...

# %%
sns.boxplot(x='zona', y='aluguel', data=df_filtrado)

# %%
sns.boxplot(x='zona', y='area', data=df_filtrado)
